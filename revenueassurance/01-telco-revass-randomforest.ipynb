# %% [markdown]
# # Telecom Revenue Assurance AI Model (El Classico with Ensemble)
# Author: Fatih E. NAR
#
# ## Introduction
# In this notebook, we showcase a machine learning model to detect fraudulent cases for telecom service use. We will use a synthetic dataset with features relevant to telco user activities, such as call duration, data usage, and SMS count. The goal is to accurately identify fraudulent events to help improve revenue assurance processes in the telco domain.

# %% [markdown]
# ## Data Loading and Exploration
# We will start by loading and exploring the synthetic dataset to understand its structure and the distribution of features.

# %%
## Install dependencies
# %pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: absl-py in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: aiofiles in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 2)) (22.1.0)
# Requirement already satisfied: aiohttp in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 3)) (3.9.5)
# Requirement already satisfied: aiohttp-cors in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: aiosignal in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: aiosqlite in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 6)) (0.20.0)
# Requirement already satisfied: anyio in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 7)) (4.4.0)
# Requirement already satisfied: appengine-python-standard in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 8)) (1.1.6)
# Requirement already satisfied: appnope in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 9)) (0.1.4)
# Requirement already satisfied: argon2-cffi in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 10)) (23.1.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 11)) (21.2.0)
# Requirement already satisfied: arrow in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 12)) (1.3.0)
# Requirement already satisfied: astroid in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 13)) (3.2.2)
# Requirement already satisfied: asttokens in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 14)) (2.4.1)
# Requirement already satisfied: astunparse in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 15)) (1.6.3)
# Requirement already satisfied: async-timeout in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 16)) (4.0.3)
# Requirement already satisfied: attrs in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 17)) (23.2.0)
# Requirement already satisfied: autopep8 in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 18)) (2.0.4)
# Requirement already satisfied: Babel in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 19)) (2.15.0)
# Requirement already satisfied: bcrypt in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 20)) (4.1.3)
# Requirement already satisfied: beautifulsoup4 in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 21)) (4.12.3)
# Requirement already satisfied: black in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 22)) (24.4.2)
# Requirement already satisfied: bleach in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 23)) (6.1.0)
# Requirement already satisfied: blessed in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 24)) (1.20.0)
# Requirement already satisfied: bokeh in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 25)) (3.4.1)
# Requirement already satisfied: boto3 in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 26)) (1.34.122)
# Requirement already satisfied: botocore in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 27)) (1.34.122)
# Requirement already satisfied: cachetools in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 28)) (5.3.3)
# Requirement already satisfied: certifi in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 29)) (2024.2.2)
# Requirement already satisfied: cffi in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 30)) (1.16.0)
# Requirement already satisfied: charset-normalizer in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 31)) (3.3.2)
# Requirement already satisfied: click in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 32)) (8.1.7)
# Requirement already satisfied: codeflare-sdk in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 33)) (0.16.3)
# Requirement already satisfied: codeflare-torchx in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 34)) (0.6.0.dev2)
# Requirement already satisfied: colorama in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 35)) (0.4.6)
# Requirement already satisfied: coloredlogs in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 36)) (15.0.1)
# Requirement already satisfied: colorful in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 37)) (0.5.6)
# Requirement already satisfied: comm in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 38)) (0.2.2)
# Requirement already satisfied: commonmark in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 39)) (0.9.1)
# Requirement already satisfied: contourpy in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 40)) (1.2.1)
# Requirement already satisfied: cryptography in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 41)) (40.0.2)
# Requirement already satisfied: cycler in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 42)) (0.12.1)
# Requirement already satisfied: debugpy in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 43)) (1.8.1)
# Requirement already satisfied: decorator in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 44)) (5.1.1)
# Requirement already satisfied: defusedxml in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 45)) (0.7.1)
# Requirement already satisfied: Deprecated in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 46)) (1.2.14)
# Requirement already satisfied: deprecation in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 47)) (2.1.0)
# Requirement already satisfied: dill in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 48)) (0.3.8)
# Requirement already satisfied: distlib in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 49)) (0.3.8)
# Requirement already satisfied: dnspython in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 50)) (2.6.1)
# Requirement already satisfied: docker in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 51)) (7.1.0)
# Requirement already satisfied: docstring-to-markdown in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 52)) (0.15)
# Requirement already satisfied: docstring_parser in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 53)) (0.8.1)
# Requirement already satisfied: entrypoints in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 54)) (0.4)
# Requirement already satisfied: exceptiongroup in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 55)) (1.2.1)
# Requirement already satisfied: executing in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 56)) (1.2.0)
# Requirement already satisfied: fastjsonschema in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 57)) (2.19.1)
# Requirement already satisfied: filelock in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 58)) (3.14.0)
# Requirement already satisfied: flake8 in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 59)) (7.0.0)
# Requirement already satisfied: Flask in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 60)) (3.0.3)
# Requirement already satisfied: flatbuffers in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 61)) (24.3.25)
# Requirement already satisfied: fonttools in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 62)) (4.51.0)
# Requirement already satisfied: fqdn in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 63)) (1.5.1)
# Requirement already satisfied: frozendict in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 64)) (2.4.4)
# Requirement already satisfied: frozenlist in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 65)) (1.4.1)
# Requirement already satisfied: fsspec in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 66)) (2024.3.1)
# Requirement already satisfied: gast in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 67)) (0.5.4)
# Requirement already satisfied: gitdb in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 68)) (4.0.11)
# Requirement already satisfied: GitPython in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 69)) (3.1.43)
# Requirement already satisfied: google-api-core in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 70)) (2.19.0)
# Requirement already satisfied: google-auth in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 71)) (2.30.0)
# Requirement already satisfied: google-auth-oauthlib in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 72)) (1.2.0)
# Requirement already satisfied: google-cloud-core in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 73)) (2.4.1)
# Requirement already satisfied: google-cloud-storage in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 74)) (2.16.0)
# Requirement already satisfied: google-crc32c in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 75)) (1.5.0)
# Requirement already satisfied: google-pasta in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 76)) (0.2.0)
# Requirement already satisfied: google-resumable-media in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 77)) (2.7.0)
# Requirement already satisfied: googleapis-common-protos in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 78)) (1.63.1)
# Requirement already satisfied: gpustat in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 79)) (1.1.1)
# Requirement already satisfied: grpcio in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 80)) (1.64.0)
# Requirement already satisfied: h5py in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 81)) (3.11.0)
# Requirement already satisfied: humanfriendly in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 82)) (10.0)
# Requirement already satisfied: idna in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 83)) (3.7)
# Requirement already satisfied: imbalanced-learn in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 84)) (0.12.3)
# Requirement already satisfied: importlib_metadata in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 85)) (7.1.0)
# Requirement already satisfied: importlib_resources in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 86)) (6.4.0)
# Requirement already satisfied: ipykernel in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 87)) (6.29.4)
# Requirement already satisfied: ipython in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 88)) (8.18.1)
# Requirement already satisfied: ipython-genutils in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 89)) (0.2.0)
# Requirement already satisfied: ipywidgets in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 90)) (8.1.2)
# Requirement already satisfied: isoduration in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 91)) (20.11.0)
# Requirement already satisfied: isort in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 92)) (5.13.2)
# Requirement already satisfied: jedi in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 93)) (0.19.1)
# Requirement already satisfied: Jinja2 in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 94)) (3.1.4)
# Requirement already satisfied: jmespath in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 95)) (1.0.1)
# Requirement already satisfied: joblib in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 96)) (1.4.2)
# Requirement already satisfied: json5 in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 97)) (0.9.25)
# Requirement already satisfied: jsonpointer in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 98)) (2.4)
# Requirement already satisfied: jsonschema in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 99)) (4.22.0)
# Requirement already satisfied: jsonschema-specifications in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 100)) (2023.12.1)
# Requirement already satisfied: jupyter-bokeh in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 101)) (4.0.5)
# Requirement already satisfied: jupyter-events in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 102)) (0.10.0)
# Requirement already satisfied: jupyter-lsp in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 103)) (2.2.5)
# Requirement already satisfied: jupyter-resource-usage in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 104)) (0.7.2)
# Requirement already satisfied: jupyter-server-mathjax in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 105)) (0.2.6)
# Requirement already satisfied: jupyter-ydoc in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 106)) (0.2.5)
# Requirement already satisfied: jupyter_client in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 107)) (7.4.9)
# Requirement already satisfied: jupyter_core in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 108)) (5.7.2)
# Requirement already satisfied: jupyter_packaging in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 109)) (0.12.3)
# Requirement already satisfied: jupyter_server in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 110)) (2.14.1)
# Requirement already satisfied: jupyter_server_fileid in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 111)) (0.9.2)
# Requirement already satisfied: jupyter_server_proxy in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 112)) (4.1.2)
# Requirement already satisfied: jupyter_server_terminals in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 113)) (0.5.3)
# Requirement already satisfied: jupyter_server_ydoc in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 114)) (0.8.0)
# Requirement already satisfied: jupyterlab in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 115)) (3.6.7)
# Requirement already satisfied: jupyterlab-lsp in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 116)) (4.3.0)
# Requirement already satisfied: jupyterlab_git in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 117)) (0.44.0)
# Requirement already satisfied: jupyterlab_pygments in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 118)) (0.3.0)
# Requirement already satisfied: jupyterlab_server in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 119)) (2.27.2)
# Requirement already satisfied: jupyterlab_widgets in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 120)) (3.0.11)
# Requirement already satisfied: kafka-python in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 121)) (2.0.2)
# Requirement already satisfied: keras in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 122)) (3.3.3)
# Requirement already satisfied: kfp in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 123)) (2.7.0)
# Requirement already satisfied: kfp-kubernetes in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 124)) (1.2.0)
# Requirement already satisfied: kfp-pipeline-spec in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 125)) (0.3.0)
# Requirement already satisfied: kfp-server-api in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 126)) (2.0.5)
# Requirement already satisfied: kiwisolver in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 127)) (1.4.5)
# Requirement already satisfied: kubernetes in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 128)) (26.1.0)
# Requirement already satisfied: libclang in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 129)) (18.1.1)
# Requirement already satisfied: Markdown in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 130)) (3.6)
# Requirement already satisfied: markdown-it-py in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 131)) (3.0.0)
# Requirement already satisfied: MarkupSafe in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 132)) (2.1.5)
# Requirement already satisfied: matplotlib in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 133)) (3.9.0)
# Requirement already satisfied: matplotlib-inline in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 134)) (0.1.7)
# Requirement already satisfied: mccabe in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 135)) (0.7.0)
# Requirement already satisfied: mdurl in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 136)) (0.1.2)
# Requirement already satisfied: micropipenv in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 137)) (1.6.0)
# Requirement already satisfied: minio in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 138)) (7.2.7)
# Requirement already satisfied: mistune in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 139)) (3.0.2)
# Requirement already satisfied: ml-dtypes in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 140)) (0.3.2)
# Requirement already satisfied: mock in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 141)) (5.1.0)
# Requirement already satisfied: mpmath in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 142)) (1.3.0)
# Requirement already satisfied: msgpack in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 143)) (1.0.8)
# Requirement already satisfied: multidict in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 144)) (6.0.5)
# Requirement already satisfied: mypy-extensions in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 145)) (1.0.0)
# Requirement already satisfied: mysql-connector-python in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 146)) (8.4.0)
# Requirement already satisfied: namex in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 147)) (0.0.8)
# Requirement already satisfied: nbclassic in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 148)) (1.1.0)
# Requirement already satisfied: nbclient in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 149)) (0.10.0)
# Requirement already satisfied: nbconvert in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 150)) (7.16.4)
# Requirement already satisfied: nbdime in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 151)) (3.2.1)
# Requirement already satisfied: nbformat in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 152)) (5.10.4)
# Requirement already satisfied: nbgitpuller in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 153)) (1.2.1)
# Requirement already satisfied: nest-asyncio in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 154)) (1.6.0)
# Requirement already satisfied: networkx in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 155)) (3.2.1)
# Requirement already satisfied: notebook in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 156)) (6.5.7)
# Requirement already satisfied: notebook_shim in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 157)) (0.2.4)
# Requirement already satisfied: nvidia-ml-py in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 158)) (12.555.43)
# Requirement already satisfied: oauthlib in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 159)) (3.2.2)
# Requirement already satisfied: odh-elyra in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 160)) (3.16.6)
# Requirement already satisfied: onnx in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 161)) (1.16.1)
# Requirement already satisfied: onnxconverter-common in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 162)) (1.13.0)
# Requirement already satisfied: onnxruntime in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 163)) (1.18.0)
# Requirement already satisfied: opencensus in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 164)) (0.11.4)
# Requirement already satisfied: opencensus-context in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 165)) (0.1.3)
# Requirement already satisfied: openshift-client in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 166)) (1.0.18)
# Requirement already satisfied: opt-einsum in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 167)) (3.3.0)
# Requirement already satisfied: optree in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 168)) (0.11.0)
# Requirement already satisfied: overrides in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 169)) (7.7.0)
# Requirement already satisfied: packaging in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 170)) (24.0)
# Requirement already satisfied: pandocfilters in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 171)) (1.5.1)
# Requirement already satisfied: papermill in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 172)) (2.6.0)
# Requirement already satisfied: paramiko in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 173)) (3.4.0)
# Requirement already satisfied: parso in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 174)) (0.8.4)
# Requirement already satisfied: pathspec in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 175)) (0.12.1)
# Requirement already satisfied: pexpect in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 176)) (4.9.0)
# Requirement already satisfied: pillow in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 177)) (10.3.0)
# Requirement already satisfied: platformdirs in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 178)) (3.11.0)
# Requirement already satisfied: plotly in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 179)) (5.22.0)
# Requirement already satisfied: pluggy in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 180)) (1.5.0)
# Requirement already satisfied: prometheus_client in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 181)) (0.20.0)
# Requirement already satisfied: prompt-toolkit in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 182)) (3.0.43)
# Requirement already satisfied: proto-plus in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 183)) (1.23.0)
# Requirement already satisfied: protobuf in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 184)) (4.25.3)
# Requirement already satisfied: psutil in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 185)) (5.9.8)
# Requirement already satisfied: psycopg in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 186)) (3.1.19)
# Requirement already satisfied: ptyprocess in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 187)) (0.7.0)
# Requirement already satisfied: pure-eval in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 188)) (0.2.2)
# Requirement already satisfied: py-spy in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 189)) (0.3.14)
# Requirement already satisfied: pyarrow in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 190)) (16.1.0)
# Requirement already satisfied: pyasn1 in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 191)) (0.6.0)
# Requirement already satisfied: pyasn1_modules in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 192)) (0.4.0)
# Requirement already satisfied: pycodestyle in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 193)) (2.11.1)
# Requirement already satisfied: pycparser in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 194)) (2.22)
# Requirement already satisfied: pycryptodome in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 195)) (3.20.0)
# Requirement already satisfied: pydantic in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 196)) (1.10.15)
# Requirement already satisfied: pydocstyle in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 197)) (6.3.0)
# Requirement already satisfied: pyflakes in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 198)) (3.2.0)
# Requirement already satisfied: PyGithub in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 199)) (2.3.0)
# Requirement already satisfied: Pygments in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 200)) (2.18.0)
# Requirement already satisfied: PyJWT in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 201)) (2.8.0)
# Requirement already satisfied: pylint in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 202)) (3.2.3)
# Requirement already satisfied: pymongo in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 203)) (4.7.3)
# Requirement already satisfied: PyNaCl in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 204)) (1.5.0)
# Requirement already satisfied: pyodbc in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 205)) (5.1.0)
# Requirement already satisfied: pyparsing in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 206)) (3.1.2)
# Requirement already satisfied: pyre-extensions in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 207)) (0.0.30)
# Requirement already satisfied: python-dateutil in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 208)) (2.9.0.post0)
# Requirement already satisfied: python-json-logger in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 209)) (2.0.7)
# Requirement already satisfied: python-lsp-jsonrpc in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 210)) (1.1.2)
# Requirement already satisfied: python-lsp-server in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 211)) (1.11.0)
# Requirement already satisfied: pytoolconfig in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 212)) (1.3.1)
# Requirement already satisfied: pytz in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 213)) (2024.1)
# Requirement already satisfied: PyYAML in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 214)) (6.0.1)
# Requirement already satisfied: pyzmq in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 215)) (26.0.3)
# Requirement already satisfied: ray in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 216)) (2.7.0)
# Requirement already satisfied: referencing in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 217)) (0.35.1)
# Requirement already satisfied: requests in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 218)) (2.32.2)
# Requirement already satisfied: requests-oauthlib in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 219)) (2.0.0)
# Requirement already satisfied: requests-toolbelt in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 220)) (0.10.1)
# Requirement already satisfied: rfc3339-validator in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 221)) (0.1.4)
# Requirement already satisfied: rfc3986-validator in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 222)) (0.1.1)
# Requirement already satisfied: rich in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 223)) (12.6.0)
# Requirement already satisfied: rope in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 224)) (1.13.0)
# Requirement already satisfied: rpds-py in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 225)) (0.18.1)
# Requirement already satisfied: rsa in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 226)) (4.9)
# Requirement already satisfied: ruamel.yaml in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 227)) (0.18.6)
# Requirement already satisfied: ruamel.yaml.clib in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 228)) (0.2.8)
# Requirement already satisfied: s3transfer in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 229)) (0.10.1)
# Requirement already satisfied: scipy in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 230)) (1.13.1)
# Requirement already satisfied: seaborn in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 231)) (0.13.2)
# Requirement already satisfied: Send2Trash in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 232)) (1.8.3)
# Requirement already satisfied: simpervisor in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 233)) (1.0.0)
# Requirement already satisfied: six in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 234)) (1.16.0)
# Requirement already satisfied: skl2onnx in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 235)) (1.17.0)
# Requirement already satisfied: smart-open in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 236)) (7.0.4)
# Requirement already satisfied: smmap in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 237)) (5.0.1)
# Requirement already satisfied: sniffio in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 238)) (1.3.1)
# Requirement already satisfied: snowballstemmer in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 239)) (2.2.0)
# Requirement already satisfied: soupsieve in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 240)) (2.5)
# Requirement already satisfied: stack-data in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 241)) (0.6.3)
# Requirement already satisfied: sympy in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 242)) (1.12)
# Requirement already satisfied: tabulate in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 243)) (0.9.0)
# Requirement already satisfied: tenacity in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 244)) (8.3.0)
# Requirement already satisfied: tensorboard in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 245)) (2.16.2)
# Requirement already satisfied: tensorboard-data-server in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 246)) (0.7.2)
# Requirement already satisfied: tensorflow in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 247)) (2.16.1)
# Requirement already satisfied: tensorflow-estimator in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 248)) (2.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 249)) (0.37.0)
# Requirement already satisfied: termcolor in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 250)) (2.3.0)
# Requirement already satisfied: terminado in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 251)) (0.18.1)
# Requirement already satisfied: tf2onnx in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 252)) (1.8.4)
# Requirement already satisfied: threadpoolctl in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 253)) (3.5.0)
# Requirement already satisfied: tinycss2 in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 254)) (1.3.0)
# Requirement already satisfied: toml in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 255)) (0.10.2)
# Requirement already satisfied: tomli in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 256)) (2.0.1)
# Requirement already satisfied: tomlkit in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 257)) (0.12.5)
# Requirement already satisfied: tornado in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 258)) (6.4)
# Requirement already satisfied: tqdm in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 259)) (4.66.4)
# Requirement already satisfied: traitlets in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 260)) (5.14.3)
# Requirement already satisfied: types-python-dateutil in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 261)) (2.9.0.20240316)
# Requirement already satisfied: typing-inspect in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 262)) (0.9.0)
# Requirement already satisfied: typing_extensions in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 263)) (4.11.0)
# Requirement already satisfied: tzdata in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 264)) (2024.1)
# Requirement already satisfied: ujson in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 265)) (5.10.0)
# Requirement already satisfied: uri-template in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 266)) (1.3.0)
# Requirement already satisfied: urllib3 in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 267)) (1.26.18)
# Requirement already satisfied: virtualenv in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 268)) (20.21.0)
# Requirement already satisfied: watchdog in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 269)) (4.0.1)
# Requirement already satisfied: wcwidth in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 270)) (0.2.13)
# Requirement already satisfied: webcolors in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 271)) (24.6.0)
# Requirement already satisfied: webencodings in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 272)) (0.5.1)
# Requirement already satisfied: websocket-client in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 273)) (1.8.0)
# Requirement already satisfied: Werkzeug in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 274)) (3.0.3)
# Requirement already satisfied: whatthepatch in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 275)) (1.0.5)
# Requirement already satisfied: widgetsnbextension in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 276)) (4.0.11)
# Requirement already satisfied: wrapt in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 277)) (1.16.0)
# Requirement already satisfied: xyzservices in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 278)) (2024.6.0)
# Requirement already satisfied: y-py in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 279)) (0.6.2)
# Requirement already satisfied: yapf in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 280)) (0.40.2)
# Requirement already satisfied: yarl in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 281)) (1.9.4)
# Requirement already satisfied: yaspin in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 282)) (3.0.2)
# Requirement already satisfied: ypy-websocket in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 283)) (0.8.4)
# Requirement already satisfied: zipp in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 284)) (3.18.2)
# Requirement already satisfied: transformers in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 285)) (4.41.2)
# Requirement already satisfied: datasets in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 286)) (2.19.1)
# Requirement already satisfied: accelerate in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 287)) (0.30.1)
# Requirement already satisfied: torch in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 288)) (2.2.2)
# Requirement already satisfied: scikit-learn in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 289)) (1.5.0)
# Requirement already satisfied: pandas in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 290)) (2.2.2)
# Requirement already satisfied: numpy in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 291)) (1.26.4)
# Requirement already satisfied: peft in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 292)) (0.11.2.dev0)
# Requirement already satisfied: bitsandbytes in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 293)) (0.42.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from astunparse->-r requirements.txt (line 15)) (0.37.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from Flask->-r requirements.txt (line 60)) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from Flask->-r requirements.txt (line 60)) (1.8.2)
# Requirement already satisfied: setuptools>=60.2.0 in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from jupyter_packaging->-r requirements.txt (line 109)) (70.0.0)
# Requirement already satisfied: pip>=9 in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from micropipenv->-r requirements.txt (line 137)) (24.0)
# Requirement already satisfied: ansicolors in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from papermill->-r requirements.txt (line 172)) (1.1.8)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from transformers->-r requirements.txt (line 285)) (0.23.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from transformers->-r requirements.txt (line 285)) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from transformers->-r requirements.txt (line 285)) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from transformers->-r requirements.txt (line 285)) (0.4.3)
# Requirement already satisfied: pyarrow-hotfix in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from datasets->-r requirements.txt (line 286)) (0.6)
# Requirement already satisfied: xxhash in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from datasets->-r requirements.txt (line 286)) (3.4.1)
# Requirement already satisfied: multiprocess in /Users/fenar/Library/Python/3.9/lib/python/site-packages (from datasets->-r requirements.txt (line 286)) (0.70.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
import lzma
import shutil
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# Extract the .xz file
with lzma.open('data/telecom_revass_data.csv.xz', 'rb') as f_in:
    with open('data/telecom_revass_data.csv', 'wb') as f_out:
        shutil.copyfileobj(f_in, f_out)

# Load the synthetic telecom data
data_path = "data/telecom_revass_data.csv"
data = pd.read_csv(data_path)

# Display basic information about the dataset
data.info()

# Display the first few rows of the dataset
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   Call_Duration               1000000 non-null  float64
#  1   Data_Usage                  1000000 non-null  float64
#  2   Sms_Count                   1000000 non-null  int64
#  3   Roaming_Indicator           1000000 non-null  int64
#  4   MobileWallet_Use            1000000 non-null  int64
#  5   Plan_Type                   1000000 non-null  object
#  6   Cost                        1000000 non-null  float64
#  7   Cellular_Location_Distance  1000000 non-null  float64
#  8   Personal_Pin_Used           1000000 non-null  int64
#  9   Avg_Call_Duration           1000000 non-null  float64
#  10  Avg_Data_Usage              1000000 non-null  float64
#  11  Avg_Cost                    1000000 non-null  float64
#  12  Fraud                       1000000 non-null  int64
# dtypes: float64(7), int64(5), object(1)
# memory usage: 99.2+ MB
#    Call_Duration   Data_Usage  Sms_Count  Roaming_Indicator  MobileWallet_Use  \
# 0       4.692681   539.146554          1                  0                 0
# 1      30.101214   247.225104          4                  0                 0
# 2      13.167457   117.971674          3                  0                 0
# 3       9.129426   411.883231          4                  0                 0
# 4       1.696249  1134.432099          4                  0                 0
#
#   Plan_Type       Cost  Cellular_Location_Distance  Personal_Pin_Used  \
# 0  postpaid  56.991170                    3.629675                  0
# 1  postpaid   9.718698                    3.654629                  0
# 2  postpaid  10.770598                    2.506765                  0
# 3  postpaid   5.885960                    0.098861                  0
# 4   prepaid  49.433863                    4.204570                  0
#
#    Avg_Call_Duration  Avg_Data_Usage   Avg_Cost  Fraud
# 0           1.460109      336.312984  71.603238      0
# 1          30.817472      150.969590  -3.794503      0
# 2          13.554912       79.394244   4.581320      0
# 3           7.990501      317.191998  24.955166      0
# 4           0.159457     1073.585260  43.517320      0

# %% [markdown]
# ## Data Preprocessing
# Before training the model, we need to preprocess the data. This includes handling missing values, converting categorical variables to numeric, and splitting the data into training and testing sets.

# %%
from sklearn.model_selection import train_test_split

# Check for missing values
missing_values = data.isnull().sum()
print("Missing values in each column:", missing_values)

# Convert categorical variables to numeric
data = pd.get_dummies(data, columns=['Plan_Type'], drop_first=True)

# Split the data into features and target variable
X = data.drop('Fraud', axis=1)
y = data['Fraud']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)
# Out:
# Missing values in each column: Call_Duration                 0
# Data_Usage                    0
# Sms_Count                     0
# Roaming_Indicator             0
# MobileWallet_Use              0
# Plan_Type                     0
# Cost                          0
# Cellular_Location_Distance    0
# Personal_Pin_Used             0
# Avg_Call_Duration             0
# Avg_Data_Usage                0
# Avg_Cost                      0
# Fraud                         0
# dtype: int64

# %% [markdown]
# ## Model Training
# We will use a Random Forest classifier to train the model. This involves fitting the model on the training data and then making predictions on the test data.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from imblearn.ensemble import BalancedRandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
# Initialize and train the BalancedRandomForestClassifier with Fine-tuned hyperparameters 
model = BalancedRandomForestClassifier(
    random_state=42,
    n_estimators=200,
    min_samples_split=10,
    min_samples_leaf=2,
    max_features='sqrt',
    max_depth=50,
    bootstrap=True,
    sampling_strategy='all',  # Set to 'all' to adopt future behavior
    replacement=True  # Set to 'True' to silence the warning
)
model.fit(X_train, y_train)
# Out:
# BalancedRandomForestClassifier(bootstrap=True, max_depth=50, min_samples_leaf=2,
#                                min_samples_split=10, n_estimators=200,
#                                random_state=42, replacement=True,
#                                sampling_strategy='all')

# %% [markdown]
# ## Model Evaluation
# We will evaluate the model's performance using metrics such as confusion matrix, classification report, and accuracy score.

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Make predictions on the test set with BalancedRandomForestClassifier
y_pred = model.predict(X_test)
# Evaluate the model
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)
acc_score = accuracy_score(y_test, y_pred)
print("---------------")
print("BalancedRandomForestClassifier Results:")
print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
print("\nAccuracy Score:")
print(acc_score)
print("---------------")
# Out:
# ---------------
# BalancedRandomForestClassifier Results:
# Confusion Matrix:
# [[231323      4]
#  [     2  68671]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    231327
#            1       1.00      1.00      1.00     68673
#
#     accuracy                           1.00    300000
#    macro avg       1.00      1.00      1.00    300000
# weighted avg       1.00      1.00      1.00    300000
#
#
# Accuracy Score:
# 0.99998
# ---------------

# %% [markdown]
# ## Conclusion
# In this notebook, we built a machine learning model to detect fraudulent telecom events using a synthetic dataset. The Random Forest classifier showed good performance in identifying fraud. Further steps could involve hyperparameter tuning, feature engineering, and testing with real-world data.

# %% [markdown]
# ## Saving the Model
# Finally, we will save the trained model to a file for future use.

# %%
# Save the model
model_path = "models/brfc_model.pkl"
with open(model_path, 'wb') as model_file:
    pickle.dump((model, X_train.columns.tolist()), model_file)
print(f"Revenue Assurance BalancedRandomForestClassifier Model Saved to {model_path}")
# Out:
# Revenue Assurance BalancedRandomForestClassifier Model Saved to models/brfc_model.pkl
