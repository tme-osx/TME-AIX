# %% [markdown]
# # Telecom Revenue Assurance AI Model (El Classico with Ensemble)
# Author: Fatih E. NAR
#
# ## Introduction
# In this notebook, we showcase a machine learning model to detect fraudulent cases for telecom service use. We will use a synthetic dataset with features relevant to telco user activities, such as call duration, data usage, and SMS count. The goal is to accurately identify fraudulent events to help improve revenue assurance processes in the telco domain.

# %% [markdown]
# ## Data Loading and Exploration
# We will start by loading and exploring the synthetic dataset to understand its structure and the distribution of features.

# %%
## Install dependencies
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: absl-py==2.1.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: aiofiles==22.1.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (22.1.0)
# Requirement already satisfied: aiohttp==3.9.5 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (3.9.5)
# Requirement already satisfied: aiohttp-cors==0.7.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: aiosignal==1.3.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: aiosqlite==0.20.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (0.20.0)
# Requirement already satisfied: anyio==4.3.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (4.3.0)
# Requirement already satisfied: appengine-python-standard==1.1.6 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (1.1.6)
# Requirement already satisfied: appnope==0.1.4 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (0.1.4)
# Requirement already satisfied: argon2-cffi==23.1.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (23.1.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (21.2.0)
# Requirement already satisfied: arrow==1.3.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (1.3.0)
# Requirement already satisfied: astroid==3.1.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (3.1.0)
# Requirement already satisfied: asttokens==2.4.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 14)) (2.4.1)
# Requirement already satisfied: astunparse==1.6.3 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (1.6.3)
# Requirement already satisfied: async-timeout==4.0.3 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (4.0.3)
# Requirement already satisfied: attrs==23.2.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 17)) (23.2.0)
# Requirement already satisfied: autopep8==2.0.4 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 18)) (2.0.4)
# Requirement already satisfied: Babel==2.14.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 19)) (2.14.0)
# Requirement already satisfied: bcrypt==4.1.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 20)) (4.1.2)
# Requirement already satisfied: beautifulsoup4==4.12.3 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 21)) (4.12.3)
# Requirement already satisfied: black==24.4.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 22)) (24.4.0)
# Requirement already satisfied: bleach==6.1.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 23)) (6.1.0)
# Requirement already satisfied: blessed==1.20.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 24)) (1.20.0)
# Requirement already satisfied: bokeh==3.4.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 25)) (3.4.1)
# Requirement already satisfied: boto3==1.34.89 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 26)) (1.34.89)
# Requirement already satisfied: botocore==1.34.89 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 27)) (1.34.89)
# Requirement already satisfied: cachetools==5.3.3 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 28)) (5.3.3)
# Requirement already satisfied: certifi==2024.2.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 29)) (2024.2.2)
# Requirement already satisfied: cffi==1.16.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 30)) (1.16.0)
# Requirement already satisfied: charset-normalizer==3.3.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 31)) (3.3.2)
# Requirement already satisfied: click==8.1.7 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 32)) (8.1.7)
# Requirement already satisfied: codeflare-sdk==0.16.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 33)) (0.16.0)
# Requirement already satisfied: codeflare-torchx==0.6.0.dev2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 34)) (0.6.0.dev2)
# Requirement already satisfied: colorama==0.4.6 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 35)) (0.4.6)
# Requirement already satisfied: coloredlogs==15.0.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 36)) (15.0.1)
# Requirement already satisfied: colorful==0.5.6 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 37)) (0.5.6)
# Requirement already satisfied: comm==0.2.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 38)) (0.2.2)
# Requirement already satisfied: commonmark==0.9.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 39)) (0.9.1)
# Requirement already satisfied: contourpy==1.2.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 40)) (1.2.1)
# Requirement already satisfied: cryptography==40.0.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 41)) (40.0.2)
# Requirement already satisfied: cycler==0.12.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 42)) (0.12.1)
# Requirement already satisfied: debugpy==1.8.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 43)) (1.8.1)
# Requirement already satisfied: decorator==5.1.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 44)) (5.1.1)
# Requirement already satisfied: defusedxml==0.7.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 45)) (0.7.1)
# Requirement already satisfied: Deprecated==1.2.14 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 46)) (1.2.14)
# Requirement already satisfied: deprecation==2.1.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 47)) (2.1.0)
# Requirement already satisfied: dill==0.3.8 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 48)) (0.3.8)
# Requirement already satisfied: distlib==0.3.8 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 49)) (0.3.8)
# Requirement already satisfied: dnspython==2.6.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 50)) (2.6.1)
# Requirement already satisfied: docker==7.0.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 51)) (7.0.0)
# Requirement already satisfied: docstring-to-markdown==0.15 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 52)) (0.15)
# Requirement already satisfied: docstring_parser==0.8.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 53)) (0.8.1)
# Requirement already satisfied: entrypoints==0.4 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 54)) (0.4)
# Requirement already satisfied: exceptiongroup==1.2.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 55)) (1.2.1)
# Requirement already satisfied: executing==1.2.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 56)) (1.2.0)
# Requirement already satisfied: fastjsonschema==2.19.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 57)) (2.19.1)
# Requirement already satisfied: filelock==3.13.4 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 58)) (3.13.4)
# Requirement already satisfied: flake8==7.0.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 59)) (7.0.0)
# Requirement already satisfied: flatbuffers==24.3.25 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 60)) (24.3.25)
# Requirement already satisfied: fonttools==4.51.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 61)) (4.51.0)
# Requirement already satisfied: fqdn==1.5.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 62)) (1.5.1)
# Requirement already satisfied: frozendict==2.4.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 63)) (2.4.2)
# Requirement already satisfied: frozenlist==1.4.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 64)) (1.4.1)
# Requirement already satisfied: fsspec==2024.3.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 65)) (2024.3.1)
# Requirement already satisfied: gast==0.5.4 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 66)) (0.5.4)
# Requirement already satisfied: gitdb==4.0.11 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 67)) (4.0.11)
# Requirement already satisfied: GitPython==3.1.43 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 68)) (3.1.43)
# Requirement already satisfied: google-api-core==2.18.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 69)) (2.18.0)
# Requirement already satisfied: google-auth==2.29.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 70)) (2.29.0)
# Requirement already satisfied: google-auth-oauthlib==1.2.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 71)) (1.2.0)
# Requirement already satisfied: google-cloud-core==2.4.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 72)) (2.4.1)
# Requirement already satisfied: google-cloud-storage==2.16.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 73)) (2.16.0)
# Requirement already satisfied: google-crc32c==1.5.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 74)) (1.5.0)
# Requirement already satisfied: google-pasta==0.2.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 75)) (0.2.0)
# Requirement already satisfied: google-resumable-media==2.7.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 76)) (2.7.0)
# Requirement already satisfied: googleapis-common-protos==1.63.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 77)) (1.63.0)
# Requirement already satisfied: gpustat==1.1.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 78)) (1.1.1)
# Requirement already satisfied: grpcio==1.62.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 79)) (1.62.2)
# Requirement already satisfied: h5py==3.11.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 80)) (3.11.0)
# Requirement already satisfied: humanfriendly==10.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 81)) (10.0)
# Requirement already satisfied: idna==3.7 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 82)) (3.7)
# Requirement already satisfied: imbalanced-learn==0.12.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 83)) (0.12.2)
# Requirement already satisfied: importlib_metadata==7.1.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 84)) (7.1.0)
# Requirement already satisfied: importlib_resources==6.4.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 85)) (6.4.0)
# Requirement already satisfied: ipykernel==6.29.4 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 86)) (6.29.4)
# Requirement already satisfied: ipython==8.18.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 87)) (8.18.1)
# Requirement already satisfied: ipython-genutils==0.2.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 88)) (0.2.0)
# Requirement already satisfied: ipywidgets==8.1.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 89)) (8.1.2)
# Requirement already satisfied: isoduration==20.11.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 90)) (20.11.0)
# Requirement already satisfied: isort==5.13.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 91)) (5.13.2)
# Requirement already satisfied: jedi==0.19.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 92)) (0.19.1)
# Requirement already satisfied: Jinja2==3.1.3 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 93)) (3.1.3)
# Requirement already satisfied: jmespath==1.0.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 94)) (1.0.1)
# Requirement already satisfied: joblib==1.4.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 95)) (1.4.0)
# Requirement already satisfied: json5==0.9.25 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 96)) (0.9.25)
# Requirement already satisfied: jsonpointer==2.4 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 97)) (2.4)
# Requirement already satisfied: jsonschema==4.21.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 98)) (4.21.1)
# Requirement already satisfied: jsonschema-specifications==2023.12.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 99)) (2023.12.1)
# Requirement already satisfied: jupyter-bokeh==3.0.7 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 100)) (3.0.7)
# Requirement already satisfied: jupyter-events==0.10.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 101)) (0.10.0)
# Requirement already satisfied: jupyter-lsp==2.2.5 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 102)) (2.2.5)
# Requirement already satisfied: jupyter-resource-usage==0.7.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 103)) (0.7.2)
# Requirement already satisfied: jupyter-server-mathjax==0.2.6 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 104)) (0.2.6)
# Requirement already satisfied: jupyter-ydoc==0.2.5 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 105)) (0.2.5)
# Requirement already satisfied: jupyter_client==7.4.9 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 106)) (7.4.9)
# Requirement already satisfied: jupyter_core==5.7.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 107)) (5.7.2)
# Requirement already satisfied: jupyter_packaging==0.12.3 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 108)) (0.12.3)
# Requirement already satisfied: jupyter_server==2.13.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 109)) (2.13.0)
# Requirement already satisfied: jupyter_server_fileid==0.9.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 110)) (0.9.2)
# Requirement already satisfied: jupyter_server_proxy==4.0.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 111)) (4.0.0)
# Requirement already satisfied: jupyter_server_terminals==0.5.3 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 112)) (0.5.3)
# Requirement already satisfied: jupyter_server_ydoc==0.8.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 113)) (0.8.0)
# Requirement already satisfied: jupyterlab==3.6.7 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 114)) (3.6.7)
# Requirement already satisfied: jupyterlab-lsp==4.2.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 115)) (4.2.0)
# Requirement already satisfied: jupyterlab_git==0.44.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 116)) (0.44.0)
# Requirement already satisfied: jupyterlab_pygments==0.3.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 117)) (0.3.0)
# Requirement already satisfied: jupyterlab_server==2.27.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 118)) (2.27.1)
# Requirement already satisfied: jupyterlab_widgets==3.0.10 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 119)) (3.0.10)
# Requirement already satisfied: kafka-python==2.0.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 120)) (2.0.2)
# Requirement already satisfied: keras==2.15.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 121)) (2.15.0)
# Requirement already satisfied: kfp==2.5.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 122)) (2.5.0)
# Requirement already satisfied: kfp-kubernetes==1.0.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 123)) (1.0.0)
# Requirement already satisfied: kfp-pipeline-spec==0.2.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 124)) (0.2.2)
# Requirement already satisfied: kfp-server-api==2.0.5 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 125)) (2.0.5)
# Requirement already satisfied: kiwisolver==1.4.5 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 126)) (1.4.5)
# Requirement already satisfied: kubernetes==26.1.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 127)) (26.1.0)
# Requirement already satisfied: libclang==18.1.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 128)) (18.1.1)
# Requirement already satisfied: Markdown==3.6 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 129)) (3.6)
# Requirement already satisfied: markdown-it-py==3.0.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 130)) (3.0.0)
# Requirement already satisfied: MarkupSafe==2.1.5 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 131)) (2.1.5)
# Requirement already satisfied: matplotlib==3.8.4 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 132)) (3.8.4)
# Requirement already satisfied: matplotlib-inline==0.1.7 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 133)) (0.1.7)
# Requirement already satisfied: mccabe==0.7.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 134)) (0.7.0)
# Requirement already satisfied: mdurl==0.1.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 135)) (0.1.2)
# Requirement already satisfied: micropipenv==1.6.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 136)) (1.6.0)
# Requirement already satisfied: minio==7.2.5 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 137)) (7.2.5)
# Requirement already satisfied: mistune==3.0.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 138)) (3.0.2)
# Requirement already satisfied: ml-dtypes==0.3.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 139)) (0.3.2)
# Requirement already satisfied: mock==5.1.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 140)) (5.1.0)
# Requirement already satisfied: mpmath==1.3.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 141)) (1.3.0)
# Requirement already satisfied: msgpack==1.0.8 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 142)) (1.0.8)
# Requirement already satisfied: multidict==6.0.5 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 143)) (6.0.5)
# Requirement already satisfied: mypy-extensions==1.0.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 144)) (1.0.0)
# Requirement already satisfied: mysql-connector-python==8.3.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 145)) (8.3.0)
# Requirement already satisfied: namex==0.0.8 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 146)) (0.0.8)
# Requirement already satisfied: nbclassic==1.0.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 147)) (1.0.0)
# Requirement already satisfied: nbclient==0.10.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 148)) (0.10.0)
# Requirement already satisfied: nbconvert==7.16.3 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 149)) (7.16.3)
# Requirement already satisfied: nbdime==3.2.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 150)) (3.2.1)
# Requirement already satisfied: nbformat==5.10.4 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 151)) (5.10.4)
# Requirement already satisfied: nbgitpuller==1.2.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 152)) (1.2.1)
# Requirement already satisfied: nest-asyncio==1.6.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 153)) (1.6.0)
# Requirement already satisfied: networkx==3.2.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 154)) (3.2.1)
# Requirement already satisfied: notebook==6.5.6 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 155)) (6.5.6)
# Requirement already satisfied: notebook_shim==0.2.4 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 156)) (0.2.4)
# Requirement already satisfied: numpy==1.26.4 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 157)) (1.26.4)
# Requirement already satisfied: nvidia-ml-py==12.535.133 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 158)) (12.535.133)
# Requirement already satisfied: oauthlib==3.2.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 159)) (3.2.2)
# Requirement already satisfied: odh-elyra==3.16.5 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 160)) (3.16.5)
# Requirement already satisfied: onnx==1.16.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 161)) (1.16.0)
# Requirement already satisfied: onnxconverter-common==1.13.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 162)) (1.13.0)
# Requirement already satisfied: onnxruntime==1.18.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 163)) (1.18.0)
# Requirement already satisfied: opencensus==0.11.4 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 164)) (0.11.4)
# Requirement already satisfied: opencensus-context==0.1.3 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 165)) (0.1.3)
# Requirement already satisfied: openshift-client==1.0.18 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 166)) (1.0.18)
# Requirement already satisfied: opt-einsum==3.3.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 167)) (3.3.0)
# Requirement already satisfied: optree==0.11.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 168)) (0.11.0)
# Requirement already satisfied: overrides==7.7.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 169)) (7.7.0)
# Requirement already satisfied: packaging==24.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 170)) (24.0)
# Requirement already satisfied: pandas==2.2.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 171)) (2.2.2)
# Requirement already satisfied: pandocfilters==1.5.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 172)) (1.5.1)
# Requirement already satisfied: papermill==2.5.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 173)) (2.5.0)
# Requirement already satisfied: paramiko==3.4.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 174)) (3.4.0)
# Requirement already satisfied: parso==0.8.4 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 175)) (0.8.4)
# Requirement already satisfied: pathspec==0.12.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 176)) (0.12.1)
# Requirement already satisfied: pexpect==4.9.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 177)) (4.9.0)
# Requirement already satisfied: pillow==10.3.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 178)) (10.3.0)
# Requirement already satisfied: platformdirs==3.11.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 179)) (3.11.0)
# Requirement already satisfied: plotly==5.20.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 180)) (5.20.0)
# Requirement already satisfied: pluggy==1.5.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 181)) (1.5.0)
# Requirement already satisfied: prometheus_client==0.20.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 182)) (0.20.0)
# Requirement already satisfied: prompt-toolkit==3.0.43 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 183)) (3.0.43)
# Requirement already satisfied: proto-plus==1.23.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 184)) (1.23.0)
# Requirement already satisfied: protobuf==3.20.3 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 185)) (3.20.3)
# Requirement already satisfied: psutil==5.9.8 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 186)) (5.9.8)
# Requirement already satisfied: psycopg==3.1.18 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 187)) (3.1.18)
# Requirement already satisfied: ptyprocess==0.7.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 188)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 189)) (0.2.2)
# Requirement already satisfied: py-spy==0.3.14 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 190)) (0.3.14)
# Requirement already satisfied: pyarrow==16.0.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 191)) (16.0.0)
# Requirement already satisfied: pyasn1==0.6.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 192)) (0.6.0)
# Requirement already satisfied: pyasn1_modules==0.4.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 193)) (0.4.0)
# Requirement already satisfied: pycodestyle==2.11.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 194)) (2.11.1)
# Requirement already satisfied: pycparser==2.22 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 195)) (2.22)
# Requirement already satisfied: pycryptodome==3.20.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 196)) (3.20.0)
# Requirement already satisfied: pydantic==1.10.15 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 197)) (1.10.15)
# Requirement already satisfied: pydocstyle==6.3.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 198)) (6.3.0)
# Requirement already satisfied: pyflakes==3.2.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 199)) (3.2.0)
# Requirement already satisfied: PyGithub==2.3.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 200)) (2.3.0)
# Requirement already satisfied: Pygments==2.17.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 201)) (2.17.2)
# Requirement already satisfied: PyJWT==2.8.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 202)) (2.8.0)
# Requirement already satisfied: pylint==3.1.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 203)) (3.1.0)
# Requirement already satisfied: pymongo==4.6.3 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 204)) (4.6.3)
# Requirement already satisfied: PyNaCl==1.5.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 205)) (1.5.0)
# Requirement already satisfied: pyodbc==5.1.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 206)) (5.1.0)
# Requirement already satisfied: pyparsing==3.1.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 207)) (3.1.2)
# Requirement already satisfied: pyre-extensions==0.0.30 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 208)) (0.0.30)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 209)) (2.9.0.post0)
# Requirement already satisfied: python-json-logger==2.0.7 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 210)) (2.0.7)
# Requirement already satisfied: python-lsp-jsonrpc==1.1.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 211)) (1.1.2)
# Requirement already satisfied: python-lsp-server==1.11.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 212)) (1.11.0)
# Requirement already satisfied: pytoolconfig==1.3.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 213)) (1.3.1)
# Requirement already satisfied: pytz==2024.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 214)) (2024.1)
# Requirement already satisfied: PyYAML==6.0.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 215)) (6.0.1)
# Requirement already satisfied: pyzmq==24.0.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 216)) (24.0.1)
# Requirement already satisfied: ray==2.7.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 217)) (2.7.0)
# Requirement already satisfied: referencing==0.34.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 218)) (0.34.0)
# Requirement already satisfied: requests==2.31.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 219)) (2.31.0)
# Requirement already satisfied: requests-oauthlib==2.0.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 220)) (2.0.0)
# Requirement already satisfied: requests-toolbelt==0.10.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 221)) (0.10.1)
# Requirement already satisfied: rfc3339-validator==0.1.4 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 222)) (0.1.4)
# Requirement already satisfied: rfc3986-validator==0.1.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 223)) (0.1.1)
# Requirement already satisfied: rich==12.6.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 224)) (12.6.0)
# Requirement already satisfied: rope==1.13.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 225)) (1.13.0)
# Requirement already satisfied: rpds-py==0.18.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 226)) (0.18.0)
# Requirement already satisfied: rsa==4.9 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 227)) (4.9)
# Requirement already satisfied: ruamel.yaml==0.18.6 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 228)) (0.18.6)
# Requirement already satisfied: ruamel.yaml.clib==0.2.8 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 229)) (0.2.8)
# Requirement already satisfied: s3transfer==0.10.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 230)) (0.10.1)
# Requirement already satisfied: scikit-learn==1.4.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 231)) (1.4.2)
# Requirement already satisfied: scipy==1.12.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 232)) (1.12.0)
# Requirement already satisfied: seaborn==0.13.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 233)) (0.13.2)
# Requirement already satisfied: Send2Trash==1.8.3 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 234)) (1.8.3)
# Requirement already satisfied: simpervisor==1.0.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 235)) (1.0.0)
# Requirement already satisfied: six==1.16.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 236)) (1.16.0)
# Requirement already satisfied: skl2onnx==1.16.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 237)) (1.16.0)
# Requirement already satisfied: smart-open==7.0.4 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 238)) (7.0.4)
# Requirement already satisfied: smmap==5.0.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 239)) (5.0.1)
# Requirement already satisfied: sniffio==1.3.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 240)) (1.3.1)
# Requirement already satisfied: snowballstemmer==2.2.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 241)) (2.2.0)
# Requirement already satisfied: soupsieve==2.5 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 242)) (2.5)
# Requirement already satisfied: stack-data==0.6.3 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 243)) (0.6.3)
# Requirement already satisfied: sympy==1.12 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 244)) (1.12)
# Requirement already satisfied: tabulate==0.9.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 245)) (0.9.0)
# Requirement already satisfied: tenacity==8.2.3 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 246)) (8.2.3)
# Requirement already satisfied: tensorboard==2.15.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 247)) (2.15.2)
# Requirement already satisfied: tensorboard-data-server==0.7.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 248)) (0.7.2)
# Requirement already satisfied: tensorflow==2.15.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 249)) (2.15.1)
# Requirement already satisfied: tensorflow-estimator==2.15.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 250)) (2.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.36.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 251)) (0.36.0)
# Requirement already satisfied: termcolor==2.3.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 252)) (2.3.0)
# Requirement already satisfied: terminado==0.18.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 253)) (0.18.1)
# Requirement already satisfied: tf2onnx==1.16.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 254)) (1.16.1)
# Requirement already satisfied: threadpoolctl==3.4.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 255)) (3.4.0)
# Requirement already satisfied: tinycss2==1.3.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 256)) (1.3.0)
# Requirement already satisfied: toml==0.10.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 257)) (0.10.2)
# Requirement already satisfied: tomli==2.0.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 258)) (2.0.1)
# Requirement already satisfied: tomlkit==0.12.4 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 259)) (0.12.4)
# Requirement already satisfied: tornado==6.4 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 260)) (6.4)
# Requirement already satisfied: tqdm==4.66.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 261)) (4.66.2)
# Requirement already satisfied: traitlets==5.14.3 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 262)) (5.14.3)
# Requirement already satisfied: types-python-dateutil==2.9.0.20240316 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 263)) (2.9.0.20240316)
# Requirement already satisfied: typing-inspect==0.9.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 264)) (0.9.0)
# Requirement already satisfied: typing_extensions==4.11.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 265)) (4.11.0)
# Requirement already satisfied: tzdata==2024.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 266)) (2024.1)
# Requirement already satisfied: ujson==5.9.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 267)) (5.9.0)
# Requirement already satisfied: uri-template==1.3.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 268)) (1.3.0)
# Requirement already satisfied: urllib3==1.26.18 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 269)) (1.26.18)
# Requirement already satisfied: virtualenv==20.21.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 270)) (20.21.0)
# Requirement already satisfied: watchdog==4.0.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 271)) (4.0.0)
# Requirement already satisfied: wcwidth==0.2.13 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 272)) (0.2.13)
# Requirement already satisfied: webcolors==1.13 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 273)) (1.13)
# Requirement already satisfied: webencodings==0.5.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 274)) (0.5.1)
# Requirement already satisfied: websocket-client==1.7.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 275)) (1.7.0)
# Requirement already satisfied: Werkzeug==3.0.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 276)) (3.0.2)
# Requirement already satisfied: whatthepatch==1.0.5 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 277)) (1.0.5)
# Requirement already satisfied: widgetsnbextension==4.0.10 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 278)) (4.0.10)
# Requirement already satisfied: wrapt==1.14.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 279)) (1.14.1)
# Requirement already satisfied: xyzservices==2024.4.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 280)) (2024.4.0)
# Requirement already satisfied: y-py==0.6.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 281)) (0.6.2)
# Requirement already satisfied: yapf==0.40.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 282)) (0.40.2)
# Requirement already satisfied: yarl==1.9.4 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 283)) (1.9.4)
# Requirement already satisfied: yaspin==3.0.2 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 284)) (3.0.2)
# Requirement already satisfied: ypy-websocket==0.8.4 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 285)) (0.8.4)
# Requirement already satisfied: zipp==3.18.1 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 286)) (3.18.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from astunparse==1.6.3->-r requirements.txt (line 15)) (0.43.0)
# Requirement already satisfied: setuptools>=60.2.0 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from jupyter_packaging==0.12.3->-r requirements.txt (line 108)) (69.5.1)
# Requirement already satisfied: pip>=9 in /Users/fenar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from micropipenv==1.6.0->-r requirements.txt (line 136)) (24.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the synthetic telecom data
data_path = "data/telecom_revass_data.csv"
data = pd.read_csv(data_path)

# Display basic information about the dataset
data.info()

# Display the first few rows of the dataset
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   Call_Duration               1000000 non-null  float64
#  1   Data_Usage                  1000000 non-null  float64
#  2   Sms_Count                   1000000 non-null  int64
#  3   Roaming_Indicator           1000000 non-null  int64
#  4   MobileWallet_Use            1000000 non-null  int64
#  5   Plan_Type                   1000000 non-null  object
#  6   Cost                        1000000 non-null  float64
#  7   Cellular_Location_Distance  1000000 non-null  float64
#  8   Last_Time_Pin_Used          1000000 non-null  float64
#  9   Avg_Call_Duration           1000000 non-null  float64
#  10  Avg_Data_Usage              1000000 non-null  float64
#  11  Fraud                       1000000 non-null  int64
# dtypes: float64(7), int64(4), object(1)
# memory usage: 91.6+ MB
#    Call_Duration   Data_Usage  Sms_Count  Roaming_Indicator  MobileWallet_Use  \
# 0       4.692681   539.146554          1                  0                 0
# 1      30.101214   247.225104          4                  0                 0
# 2      13.167457   117.971674          3                  0                 0
# 3       9.129426   411.883231          4                  0                 0
# 4       1.696249  1134.432099          4                  0                 0
#
#   Plan_Type       Cost  Cellular_Location_Distance  Last_Time_Pin_Used  \
# 0  postpaid  71.603238                    3.629675           46.011773
# 1  postpaid  -3.794503                    3.654629           47.339394
# 2  postpaid   4.581320                    2.506765            8.653167
# 3  postpaid  24.955166                    0.098861           18.875911
# 4   prepaid  43.517320                    4.204570           30.711223
#
#    Avg_Call_Duration  Avg_Data_Usage  Fraud
# 0           1.460109      336.312984      0
# 1          30.817472      150.969590      0
# 2          13.554912       79.394244      0
# 3           7.990501      317.191998      1
# 4           0.159457     1073.585260      0

# %% [markdown]
# ## Data Preprocessing
# Before training the model, we need to preprocess the data. This includes handling missing values, converting categorical variables to numeric, and splitting the data into training and testing sets.

# %%
from sklearn.model_selection import train_test_split

# Check for missing values
missing_values = data.isnull().sum()
print("Missing values in each column:", missing_values)

# Convert categorical variables to numeric
data = pd.get_dummies(data, columns=['Plan_Type'], drop_first=True)

# Split the data into features and target variable
X = data.drop('Fraud', axis=1)
y = data['Fraud']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)
# Out:
# Missing values in each column: Call_Duration                 0
# Data_Usage                    0
# Sms_Count                     0
# Roaming_Indicator             0
# MobileWallet_Use              0
# Plan_Type                     0
# Cost                          0
# Cellular_Location_Distance    0
# Last_Time_Pin_Used            0
# Avg_Call_Duration             0
# Avg_Data_Usage                0
# Fraud                         0
# dtype: int64

# %% [markdown]
# ## Model Training
# We will use a Random Forest classifier to train the model. This involves fitting the model on the training data and then making predictions on the test data.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from imblearn.ensemble import BalancedRandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier

# We are using Classifier (which handles non-linear relationships, robust to outliers, and can manage imbalanced datasets effectively) approach with Ensemble learning (Random Forest & Balanced Random Forest), which is a machine learning paradigm where multiple models (often referred to as "weak learners") are trained and combined to solve a particular problem. The idea is that by combining the predictions of multiple models, the ensemble can achieve better performance than any individual model alone. Ensemble learning techniques are widely used because they can significantly improve the accuracy, robustness, and generalizability of machine learning models.

# Train a Random Forest classifier with class weights
model_1 = RandomForestClassifier(n_estimators=100, random_state=42, class_weight={0: 1, 1: 10})
model_1.fit(X_train, y_train)

# Initialize and train the BalancedRandomForestClassifier with Fine-tuned hyperparameters 
model_2 = BalancedRandomForestClassifier(
    random_state=42,
    n_estimators=200,
    min_samples_split=10,
    min_samples_leaf=2,
    max_features='sqrt',
    max_depth=50,
    bootstrap=True,
    sampling_strategy='all',  # Set to 'all' to adopt future behavior
    replacement=True  # Set to 'True' to silence the warning
)
model_2.fit(X_train, y_train)

# %% [markdown]
# ## Model Evaluation
# We will evaluate the model's performance using metrics such as confusion matrix, classification report, and accuracy score.

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Make predictions on the test set with RandomForestClassifier
y_pred_1 = model_1.predict(X_test)
# Evaluate the model
print("---------------")
print("RandomForestClassifier Results:")
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_1))
print("\nClassification Report:")
print(classification_report(y_test, y_pred_1))
print("\nAccuracy Score:")
print(accuracy_score(y_test, y_pred_1))
print("---------------")

# Make predictions on the test set with BalancedRandomForestClassifier
y_pred_2 = model_2.predict(X_test)
# Evaluate the model
conf_matrix = confusion_matrix(y_test, y_pred_2)
class_report = classification_report(y_test, y_pred_2)
acc_score = accuracy_score(y_test, y_pred_2)
print("---------------")
print("BalancedRandomForestClassifier Results:")
print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
print("\nAccuracy Score:")
print(acc_score)
print("---------------")

# %% [markdown]
# ## Conclusion
# In this notebook, we built a machine learning model to detect fraudulent telecom events using a synthetic dataset. The Random Forest classifier showed good performance in identifying fraud. Further steps could involve hyperparameter tuning, feature engineering, and testing with real-world data.

# %% [markdown]
# ## Saving the Model
# Finally, we will save the trained model to a file for future use.

# %%
import joblib

# Save the model1
model1_path = "models/telecom_revenueassurance_model1.pkl"
joblib.dump(model_1, model1_path)
print(f"Model-1: RandomForestClassifier saved to {model1_path}")

# Save the model2
model2_path = "models/telecom_revenueassurance_model2.pkl"
joblib.dump(model_2, model2_path)
print(f"Model-2: BalancedRandomForestClassifier saved to {model2_path}")
